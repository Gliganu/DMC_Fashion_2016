# %%
import pandas as pd
import numpy as np

# %%
inputFileName = 'C:\\Users\\silviana campian\\Desktop\\data mining cup\\DMC_Fashion_2016\\data\\orders_train.txt'

# %%
data = pd.read_csv(inputFileName, delimiter=';', skipinitialspace=True)
data = data[:][:10000]

# %% [markdown]
# Display the data headers for reference

# %%
data.shape
# Out:
# (10000, 15)

# %%
grouped_by_orderID = data['quantity'].groupby(data['orderID'])

# %% [markdown]
# Get the size of each basket (how many distinct products there were per order) and the total quantity of each basket

# %%
aggregated[['basketSize', 'basketTotalQuantity']]  = grouped_by_orderID.agg([np.size, np.sum])

# %%
aggregated
# Out:
#           basketSize  basketTotalQuantity
# orderID
# a1000001           2                    2
# a1000002           2                    2
# a1000003           5                    4
# a1000004           1                    1
# a1000005           3                    3
# a1000006           2                    1
# a1000007           3                    3
# a1000008           1                    1
# a1000009           6                    6
# a1000010           6                    6
# a1000011           4                    4
# a1000012           2                    2
# a1000013           6                    6
# a1000014           3                    3
# a1000015           1                    1
# a1000016           2                    2
# a1000017           1                    1
# a1000018           1                    1
# a1000019           1                    1
# a1000020           3                    3
# a1000021           1                    1
# a1000022           1                    1
# a1000023           1                    1
# a1000024           9                    9
# a1000025           2                    2
# a1000026           2                    2
# a1000027           1                    1
# a1000028           3                    3
# a1000029           5                    5
# a1000030           5                    5
# ...              ...                  ...
# a1003346           3                    3
# a1003347           9                    9
# a1003348           2                    2
# a1003349           2                    2
# a1003350           5                    5
# a1003351           5                    5
# a1003352           2                    2
# a1003353           3                    3
# a1003354           1                    1
# a1003355           5                    5
# a1003356           6                    6
# a1003357           1                    1
# a1003358           1                    1
# a1003359           2                    2
# a1003360           4                    4
# a1003361           1                    1
# a1003362           3                    3
# a1003363           4                    4
# a1003364           1                    1
# a1003365           7                    7
# a1003366           3                    3
# a1003367           7                    7
# a1003368           1                    1
# a1003369           2                    2
# a1003370           8                    8
# a1003371           6                    6
# a1003372           2                    2
# a1003373           2                    2
# a1003374           1                    1
# a1003375           2                    2
#
# [3351 rows x 2 columns]

# %%
dict_basket_size = aggregated.to_dict().get('basketSize')
dict_basket_size
# Out:
# {'a1001489': 4,
#  'a1003168': 3,
#  'a1003169': 3,
#  'a1001488': 2,
#  'a1003164': 5,
#  'a1003165': 6,
#  'a1003166': 3,
#  'a1003167': 1,
#  'a1003160': 2,
#  'a1003161': 4,
#  'a1003162': 3,
#  'a1003163': 2,
#  'a1001443': 16,
#  'a1001719': 2,
#  'a1001649': 3,
#  'a1003304': 1,
#  'a1003305': 2,
#  'a1003306': 2,
#  'a1003307': 1,
#  'a1003300': 4,
#  'a1002605': 4,
#  'a1003302': 2,
#  'a1003303': 1,
#  'a1003308': 1,
#  'a1003309': 6,
#  'a1001442': 2,
#  'a1001718': 1,
#  'a1001483': 10,
#  'a1002369': 9,
#  'a1002368': 1,
#  'a1001482': 3,
#  'a1002361': 1,
#  'a1002360': 2,
#  'a1002363': 2,
#  'a1002362': 2,
#  'a1002365': 6,
#  'a1002364': 2,
#  'a1002367': 1,
#  'a1002366': 2,
#  'a1003262': 4,
#  'a1002141': 1,
#  'a1002140': 2,
#  'a1002143': 3,
#  'a1002142': 5,
#  'a1002145': 2,
#  'a1002144': 2,
#  'a1002147': 5,
#  'a1002146': 8,
#  'a1002149': 4,
#  'a1002148': 2,
#  'a1002419': 2,
#  'a1002418': 2,
#  'a1002963': 3,
#  'a1002962': 1,
#  'a1002961': 7,
#  'a1002960': 4,
#  'a1002967': 1,
#  'a1002966': 2,
#  'a1002965': 1,
#  'a1002964': 5,
#  'a1002969': 3,
#  'a1002968': 4,
#  'a1002538': 1,
#  'a1002099': 1,
#  'a1002098': 5,
#  'a1002097': 2,
#  'a1002096': 7,
#  'a1002095': 2,
#  'a1002094': 2,
#  'a1002093': 10,
#  'a1002092': 1,
#  'a1002091': 1,
#  'a1002090': 2,
#  'a1000352': 3,
#  'a1002852': 1,
#  'a1002569': 2,
#  'a1000353': 2,
#  'a1002567': 1,
#  'a1002566': 2,
#  'a1002565': 2,
#  'a1002564': 3,
#  'a1002539': 4,
#  'a1000422': 5,
#  'a1002561': 7,
#  'a1002454': 1,
#  'a1001063': 2,
#  'a1001062': 1,
#  'a1001061': 1,
#  'a1000423': 7,
#  'a1001067': 2,
#  'a1001066': 2,
#  'a1001065': 3,
#  'a1001064': 4,
#  'a1000356': 4,
#  'a1001069': 2,
#  'a1001068': 2,
#  'a1000357': 8,
#  'a1000354': 6,
#  'a1001999': 3,
#  'a1001998': 1,
#  'a1001997': 2,
#  'a1001996': 6,
#  'a1001995': 1,
#  'a1000355': 4,
#  'a1001993': 9,
#  'a1001992': 1,
#  'a1001991': 5,
#  'a1001990': 2,
#  'a1002897': 1,
#  'a1001508': 2,
#  'a1002895': 5,
#  'a1002894': 1,
#  'a1002893': 3,
#  'a1002892': 3,
#  'a1001509': 5,
#  'a1002899': 3,
#  'a1002898': 2,
#  'a1002783': 1,
#  'a1002782': 2,
#  'a1002780': 6,
#  'a1002787': 2,
#  'a1002786': 1,
#  'a1002785': 2,
#  'a1002784': 1,
#  'a1002789': 9,
#  'a1001953': 3,
#  'a1001207': 4,
#  'a1001206': 4,
#  'a1001205': 2,
#  'a1001204': 3,
#  'a1001203': 2,
#  'a1001202': 4,
#  'a1001201': 1,
#  'a1001200': 1,
#  'a1001209': 1,
#  'a1001208': 3,
#  'a1001197': 2,
#  'a1001196': 2,
#  'a1001195': 14,
#  'a1001194': 1,
#  'a1001193': 1,
#  'a1001192': 2,
#  'a1001191': 4,
#  'a1001190': 8,
#  'a1002451': 2,
#  'a1001199': 4,
#  'a1001198': 5,
#  'a1000828': 3,
#  'a1000829': 1,
#  'a1003042': 2,
#  'a1000824': 1,
#  'a1000825': 3,
#  'a1000826': 3,
#  'a1000827': 4,
#  'a1000820': 2,
#  'a1000821': 3,
#  'a1000822': 3,
#  'a1000823': 6,
#  'a1001665': 2,
#  'a1001664': 2,
#  'a1001667': 3,
#  'a1001666': 3,
#  'a1001661': 5,
#  'a1001660': 6,
#  'a1001663': 1,
#  'a1001662': 2,
#  'a1001849': 4,
#  'a1001848': 1,
#  'a1001458': 6,
#  'a1001669': 1,
#  'a1000136': 4,
#  'a1000137': 2,
#  'a1000134': 3,
#  'a1000135': 6,
#  'a1000132': 4,
#  'a1000133': 3,
#  'a1000130': 4,
#  'a1000131': 1,
#  'a1001333': 3,
#  'a1000951': 8,
#  'a1001331': 2,
#  'a1001330': 1,
#  'a1001337': 1,
#  'a1001336': 5,
#  'a1000138': 1,
#  'a1000139': 1,
#  'a1001689': 2,
#  'a1001688': 3,
#  'a1001683': 2,
#  'a1001682': 1,
#  'a1001681': 2,
#  'a1001680': 1,
#  'a1001687': 21,
#  'a1001686': 2,
#  'a1001685': 1,
#  'a1001684': 2,
#  'a1003048': 5,
#  'a1001713': 3,
#  'a1000622': 2,
#  'a1000623': 7,
#  'a1000620': 1,
#  'a1000621': 2,
#  'a1000626': 1,
#  'a1000627': 1,
#  'a1000624': 1,
#  'a1000625': 5,
#  'a1001971': 2,
#  'a1000628': 4,
#  'a1000629': 3,
#  'a1000558': 3,
#  'a1000559': 2,
#  'a1000008': 1,
#  'a1000009': 6,
#  'a1002647': 3,
#  'a1000002': 2,
#  'a1000003': 5,
#  'a1000001': 2,
#  'a1000554': 1,
#  'a1000007': 3,
#  'a1000556': 2,
#  'a1000557': 3,
#  'a1001531': 1,
#  'a1001530': 11,
#  'a1001533': 2,
#  'a1001532': 5,
#  'a1001535': 5,
#  'a1001534': 2,
#  'a1001537': 6,
#  'a1001536': 4,
#  'a1001539': 2,
#  'a1001538': 5,
#  'a1002413': 5,
#  'a1002643': 1,
#  'a1002640': 2,
#  'a1002641': 1,
#  'a1000486': 2,
#  'a1000487': 2,
#  'a1000484': 1,
#  'a1000485': 1,
#  'a1000482': 4,
#  'a1000483': 1,
#  'a1000952': 1,
#  'a1000481': 2,
#  'a1000958': 5,
#  'a1000959': 12,
#  'a1000488': 3,
#  'a1000489': 1,
#  'a1003267': 1,
#  'a1003266': 1,
#  'a1000455': 2,
#  'a1001972': 1,
#  'a1003265': 1,
#  'a1000318': 3,
#  'a1000319': 5,
#  'a1000316': 3,
#  'a1000317': 2,
#  'a1000314': 7,
#  'a1000315': 3,
#  'a1000312': 1,
#  'a1000313': 2,
#  'a1000310': 3,
#  'a1000311': 3,
#  'a1002850': 2,
#  'a1000456': 1,
#  'a1000451': 1,
#  'a1002999': 2,
#  'a1000450': 1,
#  'a1001975': 2,
#  'a1000453': 8,
#  'a1000452': 2,
#  'a1001974': 5,
#  'a1001827': 1,
#  'a1001826': 4,
#  'a1001450': 1,
#  'a1001977': 4,
#  'a1001451': 3,
#  'a1001976': 2,
#  'a1003179': 1,
#  'a1003178': 4,
#  'a1003177': 5,
#  'a1003176': 1,
#  'a1003175': 2,
#  'a1003174': 5,
#  'a1003173': 1,
#  'a1003172': 7,
#  'a1003171': 5,
#  'a1003170': 3,
#  'a1001708': 1,
#  'a1001658': 1,
#  'a1001829': 3,
#  'a1001828': 3,
#  'a1003317': 1,
#  'a1000653': 2,
#  'a1003315': 1,
#  'a1003314': 1,
#  'a1001457': 2,
#  'a1003312': 3,
#  'a1003311': 3,
#  'a1001259': 2,
#  'a1001313': 6,
#  'a1001709': 3,
#  'a1001659': 2,
#  'a1001312': 4,
#  'a1002879': 2,
#  'a1002318': 2,
#  'a1002319': 2,
#  'a1002314': 2,
#  'a1002315': 4,
#  'a1002316': 1,
#  'a1002310': 1,
#  'a1002311': 4,
#  'a1002312': 1,
#  'a1002313': 4,
#  'a1001319': 4,
#  'a1001318': 5,
#  'a1001252': 2,
#  'a1002134': 3,
#  'a1002135': 5,
#  'a1002136': 1,
#  'a1000658': 2,
#  'a1002130': 3,
#  'a1002131': 3,
#  'a1002132': 1,
#  'a1002133': 1,
#  'a1001706': 5,
#  'a1002138': 1,
#  'a1002139': 2,
#  'a1002428': 2,
#  'a1001707': 2,
#  'a1002956': 3,
#  'a1002957': 4,
#  'a1002954': 1,
#  'a1002955': 4,
#  'a1002952': 4,
#  'a1001704': 6,
#  'a1002950': 2,
#  'a1002951': 1,
#  'a1001705': 1,
#  'a1002958': 3,
#  'a1002959': 2,
#  'a1002220': 2,
#  'a1002221': 4,
#  'a1002222': 3,
#  'a1002223': 1,
#  'a1002224': 3,
#  'a1002225': 2,
#  'a1002226': 2,
#  'a1002227': 2,
#  'a1002228': 1,
#  'a1002229': 1,
#  'a1002558': 4,
#  'a1002559': 2,
#  'a1001056': 2,
#  'a1001057': 1,
#  'a1001054': 1,
#  'a1001055': 2,
#  'a1001052': 1,
#  'a1001050': 4,
#  'a1001051': 6,
#  'a1002040': 2,
#  'a1002041': 3,
#  'a1002042': 6,
#  'a1002043': 4,
#  'a1002044': 6,
#  'a1002045': 2,
#  'a1001058': 1,
#  'a1001059': 3,
#  'a1002410': 5,
#  'a1003344': 1,
#  'a1002417': 3,
#  'a1002416': 2,
#  'a1001702': 1,
#  'a1001656': 1,
#  'a1002713': 4,
#  'a1002414': 3,
#  'a1001703': 7,
#  'a1001957': 1,
#  'a1001700': 3,
#  'a1001650': 2,
#  'a1000839': 3,
#  'a1000838': 2,
#  'a1000837': 2,
#  'a1000836': 2,
#  'a1000835': 2,
#  'a1000834': 4,
#  'a1000833': 6,
#  'a1000832': 1,
#  'a1000831': 2,
#  'a1000830': 3,
#  'a1001834': 5,
#  'a1001835': 3,
#  'a1001836': 3,
#  'a1001837': 2,
#  'a1001830': 1,
#  'a1001831': 1,
#  'a1001832': 5,
#  'a1001833': 3,
#  'a1001838': 2,
#  'a1001839': 2,
#  'a1001701': 2,
#  'a1001651': 2,
#  'a1001308': 1,
#  'a1001309': 2,
#  'a1001306': 2,
#  'a1001307': 4,
#  'a1001304': 2,
#  'a1001305': 2,
#  'a1001302': 2,
#  'a1001303': 2,
#  'a1001300': 1,
#  'a1001301': 1,
#  'a1003370': 8,
#  'a1003345': 2,
#  'a1000635': 1,
#  'a1000634': 2,
#  'a1001238': 1,
#  'a1001239': 5,
#  'a1000631': 1,
#  'a1000630': 2,
#  'a1000633': 2,
#  'a1000632': 2,
#  'a1001232': 4,
#  'a1001233': 4,
#  'a1001230': 2,
#  'a1001231': 2,
#  'a1001236': 1,
#  'a1000638': 1,
#  'a1001234': 3,
#  'a1001235': 2,
#  'a1000549': 2,
#  'a1000548': 3,
#  'a1000019': 1,
#  'a1000018': 1,
#  'a1000015': 1,
#  'a1000014': 3,
#  'a1000017': 1,
#  'a1000016': 2,
#  'a1000547': 7,
#  'a1000546': 3,
#  'a1000545': 1,
#  'a1000544': 3,
#  'a1001544': 3,
#  'a1000727': 4,
#  'a1001546': 2,
#  'a1001547': 2,
#  'a1001540': 2,
#  'a1001541': 3,
#  'a1001542': 2,
#  'a1000726': 2,
#  'a1001548': 3,
#  'a1000725': 5,
#  'a1000499': 5,
#  'a1000498': 7,
#  'a1000724': 4,
#  'a1000491': 1,
#  'a1000490': 1,
#  'a1000493': 2,
#  'a1000492': 1,
#  'a1000495': 4,
#  'a1000494': 7,
#  'a1000497': 1,
#  'a1000496': 1,
#  'a1000947': 3,
#  'a1000128': 3,
#  'a1000945': 2,
#  'a1000944': 1,
#  'a1000943': 5,
#  'a1000721': 6,
#  'a1000941': 7,
#  'a1000940': 3,
#  'a1000121': 3,
#  'a1000120': 5,
#  'a1000123': 5,
#  'a1000122': 8,
#  'a1000125': 1,
#  'a1000124': 2,
#  'a1000127': 5,
#  'a1000126': 7,
#  'a1000301': 2,
#  'a1000300': 4,
#  'a1000303': 2,
#  'a1000302': 1,
#  'a1000305': 6,
#  'a1000304': 1,
#  'a1000307': 2,
#  'a1000306': 1,
#  'a1000309': 3,
#  'a1000308': 2,
#  'a1002829': 14,
#  'a1002568': 2,
#  'a1001711': 5,
#  'a1001629': 2,
#  'a1002563': 5,
#  'a1002562': 2,
#  'a1002560': 3,
#  'a1001955': 1,
#  'a1003094': 1,
#  'a1003095': 1,
#  'a1003096': 1,
#  'a1003097': 1,
#  'a1003090': 1,
#  'a1001628': 2,
#  'a1003092': 2,
#  'a1003093': 8,
#  'a1003098': 6,
#  'a1003099': 5,
#  'a1001060': 6,
#  'a1003218': 1,
#  'a1001968': 1,
#  'a1003142': 1,
#  'a1003143': 2,
#  'a1003140': 3,
#  'a1003141': 2,
#  'a1003146': 2,
#  'a1003147': 2,
#  'a1003144': 2,
#  'a1003145': 2,
#  'a1003148': 4,
#  'a1003149': 2,
#  'a1001969': 2,
#  'a1002309': 2,
#  'a1002308': 1,
#  'a1002307': 1,
#  'a1002306': 1,
#  'a1002305': 4,
#  'a1002304': 7,
#  'a1002303': 4,
#  'a1002302': 5,
#  'a1002301': 5,
#  'a1002300': 4,
#  'a1001710': 7,
#  'a1002127': 2,
#  'a1002126': 2,
#  'a1002125': 1,
#  'a1002124': 3,
#  'a1002123': 3,
#  'a1002122': 5,
#  'a1002121': 2,
#  'a1002120': 4,
#  'a1002941': 2,
#  'a1002940': 1,
#  'a1002943': 6,
#  'a1002942': 3,
#  'a1002945': 1,
#  'a1002944': 1,
#  'a1002129': 1,
#  'a1002128': 6,
#  'a1001964': 1,
#  'a1002415': 3,
#  'a1001994': 3,
#  'a1002084': 1,
#  'a1003196': 1,
#  'a1002233': 5,
#  'a1001965': 4,
#  'a1002231': 1,
#  'a1000096': 7,
#  'a1002237': 3,
#  'a1002236': 2,
#  'a1002235': 2,
#  'a1002234': 9,
#  'a1003322': 3,
#  'a1003323': 1,
#  'a1002239': 3,
#  'a1002238': 1,
#  'a1002549': 2,
#  'a1002548': 3,
#  'a1003324': 3,
#  'a1003325': 4,
#  'a1002059': 9,
#  'a1002058': 2,
#  'a1002896': 4,
#  'a1002053': 2,
#  'a1002052': 1,
#  'a1002051': 4,
#  'a1002050': 5,
#  'a1002057': 1,
#  'a1002056': 1,
#  'a1002055': 1,
#  'a1002054': 2,
#  'a1002856': 3,
#  'a1003190': 2,
#  'a1002890': 4,
#  'a1002439': 7,
#  'a1002438': 1,
#  'a1002431': 1,
#  'a1002430': 2,
#  'a1002433': 2,
#  'a1002432': 3,
#  'a1002435': 1,
#  'a1002434': 1,
#  'a1002437': 3,
#  'a1002436': 2,
#  'a1000802': 3,
#  'a1000803': 2,
#  'a1000800': 1,
#  'a1000801': 4,
#  'a1000806': 1,
#  'a1000807': 3,
#  'a1000804': 2,
#  'a1000805': 8,
#  'a1000808': 2,
#  'a1000809': 3,
#  'a1001049': 2,
#  'a1001048': 9,
#  'a1001825': 1,
#  'a1001824': 2,
#  'a1001823': 2,
#  'a1001822': 1,
#  'a1001821': 2,
#  'a1001820': 6,
#  'a1001041': 3,
#  'a1001040': 3,
#  'a1001043': 4,
#  'a1001042': 1,
#  'a1001045': 1,
#  'a1001044': 2,
#  'a1001047': 4,
#  'a1001046': 2,
#  'a1001311': 7,
#  'a1001310': 2,
#  'a1000798': 1,
#  'a1000799': 3,
#  'a1001315': 1,
#  'a1001314': 5,
#  'a1001317': 3,
#  'a1001316': 3,
#  'a1000792': 1,
#  'a1000793': 3,
#  'a1000790': 1,
#  'a1000791': 1,
#  'a1000796': 1,
#  'a1000797': 1,
#  'a1000794': 3,
#  'a1000795': 3,
#  'a1002788': 2,
#  'a1001959': 2,
#  'a1001958': 1,
#  'a1001229': 2,
#  'a1001228': 1,
#  'a1001225': 4,
#  'a1001224': 2,
#  'a1001227': 1,
#  'a1001226': 3,
#  'a1001221': 3,
#  'a1001220': 3,
#  'a1001223': 5,
#  'a1001222': 2,
#  'a1000578': 4,
#  'a1000579': 1,
#  'a1000576': 1,
#  'a1000577': 3,
#  'a1000574': 1,
#  'a1000575': 2,
#  'a1000572': 1,
#  'a1000573': 9,
#  'a1000570': 6,
#  'a1000571': 1,
#  'a1001557': 6,
#  'a1001556': 2,
#  'a1001555': 11,
#  'a1001554': 6,
#  'a1001553': 1,
#  'a1001552': 4,
#  'a1001551': 1,
#  'a1001550': 3,
#  'a1001559': 4,
#  'a1001558': 1,
#  'a1000978': 5,
#  'a1000979': 2,
#  'a1001712': 3,
#  'a1000972': 1,
#  'a1000973': 2,
#  'a1000970': 3,
#  'a1000971': 2,
#  'a1000976': 2,
#  'a1000977': 3,
#  'a1000974': 2,
#  'a1000975': 2,
#  'a1000158': 5,
#  'a1000159': 3,
#  'a1000154': 3,
#  'a1000155': 8,
#  'a1000156': 1,
#  'a1000157': 3,
#  'a1000150': 2,
#  'a1000151': 2,
#  'a1000152': 1,
#  'a1000153': 9,
#  'a1000950': 9,
#  'a1000374': 4,
#  'a1000375': 2,
#  'a1000376': 2,
#  'a1000377': 1,
#  'a1000370': 9,
#  'a1000371': 2,
#  'a1000372': 14,
#  'a1000373': 6,
#  'a1000722': 2,
#  'a1000378': 3,
#  'a1000379': 3,
#  'a1002912': 5,
#  'a1002913': 4,
#  'a1002910': 1,
#  'a1000208': 18,
#  'a1000209': 8,
#  'a1002911': 2,
#  'a1000200': 3,
#  'a1000201': 4,
#  'a1000202': 2,
#  'a1000203': 2,
#  'a1000204': 2,
#  'a1000205': 8,
#  'a1000206': 1,
#  'a1000207': 1,
#  'a1002914': 1,
#  'a1002915': 2,
#  'a1003087': 3,
#  'a1003086': 2,
#  'a1003085': 1,
#  'a1003084': 2,
#  'a1003083': 5,
#  'a1003082': 2,
#  'a1003081': 1,
#  'a1003080': 8,
#  'a1003089': 1,
#  'a1003088': 4,
#  'a1002502': 1,
#  'a1003155': 1,
#  'a1003154': 2,
#  'a1003157': 2,
#  'a1003156': 2,
#  'a1003151': 2,
#  'a1003150': 10,
#  'a1003153': 4,
#  'a1003152': 1,
#  'a1003159': 3,
#  'a1003158': 1,
#  'a1001922': 2,
#  'a1001923': 4,
#  'a1001920': 3,
#  'a1001921': 1,
#  'a1001926': 11,
#  'a1002681': 2,
#  'a1001291': 1,
#  'a1001924': 1,
#  'a1001925': 5,
#  'a1002332': 2,
#  'a1001841': 1,
#  'a1002330': 1,
#  'a1002331': 3,
#  'a1002336': 5,
#  'a1002337': 1,
#  'a1002334': 1,
#  'a1001840': 2,
#  'a1002338': 2,
#  'a1002339': 2,
#  'a1001843': 2,
#  'a1001842': 6,
#  'a1003316': 1,
#  'a1001845': 2,
#  'a1002456': 5,
#  'a1001844': 2,
#  'a1002688': 2,
#  'a1002689': 4,
#  'a1002938': 1,
#  'a1001847': 7,
#  'a1002682': 2,
#  'a1002683': 2,
#  'a1002680': 1,
#  'a1001846': 1,
#  'a1002686': 2,
#  'a1002687': 11,
#  'a1002684': 2,
#  'a1002685': 3,
#  'a1001105': 2,
#  'a1001952': 3,
#  'a1002206': 1,
#  'a1002207': 2,
#  'a1002204': 2,
#  'a1002205': 6,
#  'a1002202': 5,
#  'a1002203': 5,
#  'a1002200': 4,
#  'a1002201': 5,
#  'a1003335': 1,
#  'a1003334': 4,
#  'a1003337': 3,
#  'a1001103': 3,
#  'a1003331': 2,
#  'a1003330': 5,
#  'a1002208': 4,
#  'a1002209': 2,
#  'a1001951': 2,
#  'a1003020': 2,
#  'a1002068': 5,
#  'a1002069': 1,
#  'a1002066': 8,
#  'a1002067': 3,
#  'a1002064': 2,
#  'a1002065': 2,
#  'a1002062': 7,
#  'a1001339': 3,
#  'a1002060': 4,
#  'a1002061': 3,
#  'a1002840': 2,
#  'a1002841': 1,
#  'a1002842': 8,
#  'a1001338': 1,
#  'a1002844': 2,
#  'a1002845': 1,
#  'a1002598': 4,
#  'a1002599': 4,
#  'a1002596': 2,
#  'a1001449': 1,
#  'a1002594': 5,
#  'a1002595': 1,
#  'a1002592': 3,
#  'a1002593': 1,
#  'a1002590': 2,
#  'a1001448': 1,
#  'a1002615': 3,
#  'a1002614': 1,
#  'a1002830': 6,
#  'a1002617': 1,
#  'a1001445': 8,
#  'a1002118': 3,
#  'a1002119': 1,
#  'a1002448': 2,
#  'a1002449': 5,
#  'a1001332': 4,
#  'a1002112': 4,
#  'a1002113': 2,
#  'a1002110': 3,
#  'a1002111': 5,
#  'a1002116': 3,
#  'a1001447': 5,
#  'a1002114': 2,
#  'a1002115': 2,
#  'a1001140': 1,
#  'a1001141': 1,
#  'a1001142': 2,
#  'a1001143': 3,
#  'a1001144': 1,
#  'a1001145': 1,
#  'a1001146': 1,
#  'a1001147': 3,
#  'a1001148': 2,
#  'a1001149': 1,
#  'a1002612': 4,
#  'a1001440': 3,
#  'a1001335': 1,
#  'a1003117': 3,
#  'a1001334': 3,
#  'a1003210': 3,
#  'a1001444': 1,
#  'a1000815': 2,
#  'a1000814': 1,
#  'a1000817': 1,
#  'a1000816': 1,
#  'a1000811': 3,
#  'a1000810': 2,
#  'a1000813': 1,
#  'a1000812': 10,
#  'a1001812': 1,
#  'a1001813': 1,
#  'a1001810': 20,
#  'a1001811': 3,
#  'a1000819': 5,
#  'a1000818': 3,
#  'a1001814': 2,
#  'a1001815': 3,
#  'a1001038': 1,
#  'a1001039': 2,
#  'a1001034': 1,
#  'a1001035': 2,
#  'a1001036': 1,
#  'a1001037': 2,
#  'a1001030': 5,
#  'a1001031': 5,
#  'a1001032': 3,
#  'a1001033': 1,
#  'a1001364': 3,
#  'a1001365': 3,
#  'a1001366': 1,
#  'a1001367': 1,
#  'a1000789': 3,
#  'a1000788': 4,
#  'a1001362': 2,
#  'a1001363': 2,
#  'a1000785': 1,
#  'a1000784': 3,
#  'a1000787': 2,
#  'a1000786': 3,
#  'a1001368': 3,
#  'a1000780': 2,
#  'a1000783': 2,
#  'a1000782': 4,
#  'a1001954': 1,
#  'a1001729': 4,
#  'a1001782': 4,
#  'a1001783': 1,
#  'a1001780': 1,
#  'a1001781': 3,
#  'a1001786': 2,
#  'a1001787': 2,
#  'a1001784': 1,
#  'a1001785': 2,
#  'a1001966': 4,
#  'a1001967': 1,
#  'a1001788': 2,
#  'a1001789': 2,
#  'a1001962': 2,
#  'a1001963': 1,
#  'a1001960': 4,
#  'a1001961': 6,
#  'a1000561': 2,
#  'a1000560': 3,
#  'a1000563': 2,
#  'a1000562': 2,
#  'a1000565': 4,
#  'a1000564': 2,
#  'a1000567': 3,
#  'a1000566': 4,
#  'a1000569': 2,
#  'a1000568': 2,
#  'a1001560': 1,
#  'a1001561': 1,
#  'a1001566': 2,
#  'a1001567': 5,
#  'a1001564': 4,
#  'a1001565': 5,
#  'a1001768': 1,
#  'a1001769': 2,
#  'a1001760': 2,
#  'a1001761': 2,
#  'a1001762': 1,
#  'a1001763': 7,
#  'a1001764': 2,
#  'a1001765': 1,
#  'a1001766': 1,
#  'a1001767': 3,
#  'a1000969': 2,
#  'a1000968': 1,
#  'a1000965': 2,
#  'a1000964': 1,
#  'a1000967': 2,
#  'a1000966': 1,
#  'a1000961': 1,
#  'a1000960': 2,
#  'a1000962': 3,
#  'a1000149': 4,
#  'a1000148': 4,
#  'a1000147': 3,
#  'a1000146': 5,
#  'a1000145': 2,
#  'a1000144': 6,
#  'a1000143': 8,
#  'a1000142': 1,
#  'a1000141': 1,
#  'a1000140': 1,
#  'a1000367': 2,
#  'a1000365': 4,
#  'a1000364': 9,
#  'a1000363': 3,
#  'a1000362': 3,
#  'a1000361': 4,
#  'a1000360': 6,
#  'a1000369': 1,
#  'a1000368': 5,
#  'a1002981': 1,
#  'a1002980': 2,
#  'a1003319': 4,
#  'a1000731': 3,
#  'a1000219': 5,
#  'a1000218': 1,
#  'a1000213': 2,
#  'a1000212': 1,
#  'a1000211': 3,
#  'a1000210': 2,
#  'a1000217': 1,
#  'a1000216': 1,
#  'a1000215': 1,
#  'a1000214': 2,
#  'a1003064': 5,
#  'a1002745': 1,
#  'a1001725': 3,
#  'a1000901': 2,
#  'a1001865': 5,
#  'a1000550': 2,
#  'a1002461': 2,
#  'a1000551': 5,
#  'a1002835': 3,
#  'a1002889': 4,
#  'a1000553': 7,
#  'a1002464': 5,
#  'a1003188': 3,
#  'a1003189': 4,
#  'a1003186': 10,
#  'a1000006': 2,
#  'a1003184': 5,
#  ...}

# %%
dict_basket_total_quantity = aggregated.to_dict().get('basketTotalQuantity')
dict_basket_total_quantity
# Out:
# {'a1001489': 4,
#  'a1003168': 3,
#  'a1003169': 3,
#  'a1001488': 2,
#  'a1003164': 5,
#  'a1003165': 6,
#  'a1003166': 3,
#  'a1003167': 1,
#  'a1003160': 2,
#  'a1003161': 4,
#  'a1003162': 3,
#  'a1003163': 2,
#  'a1001443': 17,
#  'a1001719': 2,
#  'a1001649': 3,
#  'a1003304': 1,
#  'a1003305': 2,
#  'a1003306': 2,
#  'a1003307': 1,
#  'a1003300': 4,
#  'a1002605': 4,
#  'a1003302': 2,
#  'a1003303': 1,
#  'a1003308': 1,
#  'a1003309': 6,
#  'a1001442': 2,
#  'a1001718': 1,
#  'a1001483': 11,
#  'a1002369': 11,
#  'a1002368': 1,
#  'a1001482': 3,
#  'a1002361': 1,
#  'a1002360': 2,
#  'a1002363': 2,
#  'a1002362': 2,
#  'a1002365': 6,
#  'a1002364': 2,
#  'a1002367': 1,
#  'a1002366': 2,
#  'a1003262': 4,
#  'a1002141': 1,
#  'a1002140': 2,
#  'a1002143': 3,
#  'a1002142': 5,
#  'a1002145': 2,
#  'a1002144': 2,
#  'a1002147': 5,
#  'a1002146': 8,
#  'a1002149': 4,
#  'a1002148': 2,
#  'a1002419': 2,
#  'a1002418': 2,
#  'a1002963': 3,
#  'a1002962': 1,
#  'a1002961': 7,
#  'a1002960': 4,
#  'a1002967': 1,
#  'a1002966': 2,
#  'a1002965': 1,
#  'a1002964': 5,
#  'a1002969': 2,
#  'a1002968': 4,
#  'a1002538': 1,
#  'a1002099': 1,
#  'a1002098': 5,
#  'a1002097': 2,
#  'a1002096': 6,
#  'a1002095': 2,
#  'a1002094': 2,
#  'a1002093': 10,
#  'a1002092': 1,
#  'a1002091': 1,
#  'a1002090': 2,
#  'a1000352': 3,
#  'a1002852': 1,
#  'a1002569': 2,
#  'a1000353': 2,
#  'a1002567': 1,
#  'a1002566': 2,
#  'a1002565': 2,
#  'a1002564': 3,
#  'a1002539': 4,
#  'a1000422': 5,
#  'a1002561': 7,
#  'a1002454': 1,
#  'a1001063': 2,
#  'a1001062': 1,
#  'a1001061': 1,
#  'a1000423': 7,
#  'a1001067': 2,
#  'a1001066': 2,
#  'a1001065': 4,
#  'a1001064': 4,
#  'a1000356': 4,
#  'a1001069': 2,
#  'a1001068': 2,
#  'a1000357': 8,
#  'a1000354': 6,
#  'a1001999': 3,
#  'a1001998': 1,
#  'a1001997': 2,
#  'a1001996': 6,
#  'a1001995': 1,
#  'a1000355': 4,
#  'a1001993': 9,
#  'a1001992': 1,
#  'a1001991': 5,
#  'a1001990': 2,
#  'a1002897': 1,
#  'a1001508': 2,
#  'a1002895': 5,
#  'a1002894': 1,
#  'a1002893': 3,
#  'a1002892': 3,
#  'a1001509': 5,
#  'a1002899': 3,
#  'a1002898': 2,
#  'a1002783': 1,
#  'a1002782': 2,
#  'a1002780': 6,
#  'a1002787': 2,
#  'a1002786': 1,
#  'a1002785': 2,
#  'a1002784': 1,
#  'a1002789': 8,
#  'a1001953': 3,
#  'a1001207': 4,
#  'a1001206': 4,
#  'a1001205': 2,
#  'a1001204': 3,
#  'a1001203': 2,
#  'a1001202': 4,
#  'a1001201': 1,
#  'a1001200': 1,
#  'a1001209': 1,
#  'a1001208': 3,
#  'a1001197': 2,
#  'a1001196': 2,
#  'a1001195': 14,
#  'a1001194': 1,
#  'a1001193': 1,
#  'a1001192': 2,
#  'a1001191': 4,
#  'a1001190': 8,
#  'a1002451': 2,
#  'a1001199': 4,
#  'a1001198': 5,
#  'a1000828': 3,
#  'a1000829': 1,
#  'a1003042': 2,
#  'a1000824': 1,
#  'a1000825': 3,
#  'a1000826': 3,
#  'a1000827': 3,
#  'a1000820': 2,
#  'a1000821': 3,
#  'a1000822': 3,
#  'a1000823': 6,
#  'a1001665': 2,
#  'a1001664': 2,
#  'a1001667': 3,
#  'a1001666': 3,
#  'a1001661': 5,
#  'a1001660': 6,
#  'a1001663': 1,
#  'a1001662': 2,
#  'a1001849': 4,
#  'a1001848': 1,
#  'a1001458': 6,
#  'a1001669': 1,
#  'a1000136': 4,
#  'a1000137': 2,
#  'a1000134': 3,
#  'a1000135': 6,
#  'a1000132': 4,
#  'a1000133': 3,
#  'a1000130': 4,
#  'a1000131': 1,
#  'a1001333': 3,
#  'a1000951': 8,
#  'a1001331': 2,
#  'a1001330': 1,
#  'a1001337': 1,
#  'a1001336': 5,
#  'a1000138': 1,
#  'a1000139': 1,
#  'a1001689': 2,
#  'a1001688': 3,
#  'a1001683': 2,
#  'a1001682': 1,
#  'a1001681': 2,
#  'a1001680': 1,
#  'a1001687': 22,
#  'a1001686': 2,
#  'a1001685': 1,
#  'a1001684': 2,
#  'a1003048': 5,
#  'a1001713': 3,
#  'a1000622': 2,
#  'a1000623': 7,
#  'a1000620': 1,
#  'a1000621': 2,
#  'a1000626': 1,
#  'a1000627': 1,
#  'a1000624': 1,
#  'a1000625': 5,
#  'a1001971': 2,
#  'a1000628': 4,
#  'a1000629': 3,
#  'a1000558': 3,
#  'a1000559': 2,
#  'a1000008': 1,
#  'a1000009': 6,
#  'a1002647': 3,
#  'a1000002': 2,
#  'a1000003': 4,
#  'a1000001': 2,
#  'a1000554': 1,
#  'a1000007': 3,
#  'a1000556': 2,
#  'a1000557': 3,
#  'a1001531': 1,
#  'a1001530': 11,
#  'a1001533': 2,
#  'a1001532': 5,
#  'a1001535': 5,
#  'a1001534': 2,
#  'a1001537': 6,
#  'a1001536': 4,
#  'a1001539': 2,
#  'a1001538': 5,
#  'a1002413': 5,
#  'a1002643': 1,
#  'a1002640': 2,
#  'a1002641': 1,
#  'a1000486': 2,
#  'a1000487': 2,
#  'a1000484': 1,
#  'a1000485': 1,
#  'a1000482': 4,
#  'a1000483': 1,
#  'a1000952': 1,
#  'a1000481': 2,
#  'a1000958': 5,
#  'a1000959': 12,
#  'a1000488': 3,
#  'a1000489': 1,
#  'a1003267': 1,
#  'a1003266': 1,
#  'a1000455': 2,
#  'a1001972': 1,
#  'a1003265': 1,
#  'a1000318': 3,
#  'a1000319': 5,
#  'a1000316': 3,
#  'a1000317': 2,
#  'a1000314': 7,
#  'a1000315': 3,
#  'a1000312': 1,
#  'a1000313': 2,
#  'a1000310': 3,
#  'a1000311': 3,
#  'a1002850': 2,
#  'a1000456': 1,
#  'a1000451': 1,
#  'a1002999': 2,
#  'a1000450': 2,
#  'a1001975': 2,
#  'a1000453': 8,
#  'a1000452': 2,
#  'a1001974': 5,
#  'a1001827': 1,
#  'a1001826': 4,
#  'a1001450': 1,
#  'a1001977': 4,
#  'a1001451': 3,
#  'a1001976': 2,
#  'a1003179': 1,
#  'a1003178': 4,
#  'a1003177': 5,
#  'a1003176': 1,
#  'a1003175': 2,
#  'a1003174': 5,
#  'a1003173': 1,
#  'a1003172': 7,
#  'a1003171': 5,
#  'a1003170': 3,
#  'a1001708': 1,
#  'a1001658': 1,
#  'a1001829': 3,
#  'a1001828': 3,
#  'a1003317': 1,
#  'a1000653': 2,
#  'a1003315': 1,
#  'a1003314': 1,
#  'a1001457': 2,
#  'a1003312': 3,
#  'a1003311': 3,
#  'a1001259': 2,
#  'a1001313': 6,
#  'a1001709': 3,
#  'a1001659': 2,
#  'a1001312': 4,
#  'a1002879': 2,
#  'a1002318': 2,
#  'a1002319': 2,
#  'a1002314': 2,
#  'a1002315': 4,
#  'a1002316': 1,
#  'a1002310': 1,
#  'a1002311': 4,
#  'a1002312': 1,
#  'a1002313': 4,
#  'a1001319': 4,
#  'a1001318': 5,
#  'a1001252': 2,
#  'a1002134': 3,
#  'a1002135': 5,
#  'a1002136': 1,
#  'a1000658': 2,
#  'a1002130': 3,
#  'a1002131': 3,
#  'a1002132': 1,
#  'a1002133': 1,
#  'a1001706': 5,
#  'a1002138': 1,
#  'a1002139': 2,
#  'a1002428': 2,
#  'a1001707': 2,
#  'a1002956': 3,
#  'a1002957': 4,
#  'a1002954': 1,
#  'a1002955': 4,
#  'a1002952': 4,
#  'a1001704': 6,
#  'a1002950': 2,
#  'a1002951': 1,
#  'a1001705': 1,
#  'a1002958': 3,
#  'a1002959': 2,
#  'a1002220': 1,
#  'a1002221': 4,
#  'a1002222': 2,
#  'a1002223': 1,
#  'a1002224': 3,
#  'a1002225': 2,
#  'a1002226': 2,
#  'a1002227': 2,
#  'a1002228': 1,
#  'a1002229': 1,
#  'a1002558': 4,
#  'a1002559': 2,
#  'a1001056': 2,
#  'a1001057': 1,
#  'a1001054': 1,
#  'a1001055': 2,
#  'a1001052': 1,
#  'a1001050': 4,
#  'a1001051': 6,
#  'a1002040': 2,
#  'a1002041': 3,
#  'a1002042': 6,
#  'a1002043': 4,
#  'a1002044': 6,
#  'a1002045': 2,
#  'a1001058': 1,
#  'a1001059': 3,
#  'a1002410': 5,
#  'a1003344': 1,
#  'a1002417': 4,
#  'a1002416': 2,
#  'a1001702': 1,
#  'a1001656': 1,
#  'a1002713': 3,
#  'a1002414': 3,
#  'a1001703': 7,
#  'a1001957': 1,
#  'a1001700': 3,
#  'a1001650': 2,
#  'a1000839': 3,
#  'a1000838': 2,
#  'a1000837': 2,
#  'a1000836': 2,
#  'a1000835': 2,
#  'a1000834': 5,
#  'a1000833': 6,
#  'a1000832': 1,
#  'a1000831': 2,
#  'a1000830': 3,
#  'a1001834': 5,
#  'a1001835': 3,
#  'a1001836': 3,
#  'a1001837': 2,
#  'a1001830': 1,
#  'a1001831': 1,
#  'a1001832': 6,
#  'a1001833': 3,
#  'a1001838': 2,
#  'a1001839': 2,
#  'a1001701': 2,
#  'a1001651': 2,
#  'a1001308': 1,
#  'a1001309': 2,
#  'a1001306': 2,
#  'a1001307': 5,
#  'a1001304': 2,
#  'a1001305': 2,
#  'a1001302': 2,
#  'a1001303': 2,
#  'a1001300': 1,
#  'a1001301': 1,
#  'a1003370': 8,
#  'a1003345': 2,
#  'a1000635': 1,
#  'a1000634': 1,
#  'a1001238': 1,
#  'a1001239': 5,
#  'a1000631': 1,
#  'a1000630': 2,
#  'a1000633': 2,
#  'a1000632': 2,
#  'a1001232': 4,
#  'a1001233': 4,
#  'a1001230': 2,
#  'a1001231': 2,
#  'a1001236': 1,
#  'a1000638': 1,
#  'a1001234': 3,
#  'a1001235': 2,
#  'a1000549': 2,
#  'a1000548': 3,
#  'a1000019': 1,
#  'a1000018': 1,
#  'a1000015': 1,
#  'a1000014': 3,
#  'a1000017': 1,
#  'a1000016': 2,
#  'a1000547': 7,
#  'a1000546': 3,
#  'a1000545': 1,
#  'a1000544': 3,
#  'a1001544': 3,
#  'a1000727': 4,
#  'a1001546': 2,
#  'a1001547': 2,
#  'a1001540': 2,
#  'a1001541': 3,
#  'a1001542': 1,
#  'a1000726': 2,
#  'a1001548': 3,
#  'a1000725': 5,
#  'a1000499': 5,
#  'a1000498': 7,
#  'a1000724': 4,
#  'a1000491': 1,
#  'a1000490': 1,
#  'a1000493': 2,
#  'a1000492': 1,
#  'a1000495': 4,
#  'a1000494': 7,
#  'a1000497': 1,
#  'a1000496': 1,
#  'a1000947': 3,
#  'a1000128': 3,
#  'a1000945': 2,
#  'a1000944': 1,
#  'a1000943': 5,
#  'a1000721': 6,
#  'a1000941': 7,
#  'a1000940': 3,
#  'a1000121': 3,
#  'a1000120': 5,
#  'a1000123': 5,
#  'a1000122': 8,
#  'a1000125': 1,
#  'a1000124': 2,
#  'a1000127': 5,
#  'a1000126': 7,
#  'a1000301': 2,
#  'a1000300': 4,
#  'a1000303': 2,
#  'a1000302': 1,
#  'a1000305': 6,
#  'a1000304': 1,
#  'a1000307': 2,
#  'a1000306': 1,
#  'a1000309': 3,
#  'a1000308': 2,
#  'a1002829': 15,
#  'a1002568': 2,
#  'a1001711': 4,
#  'a1001629': 2,
#  'a1002563': 5,
#  'a1002562': 2,
#  'a1002560': 3,
#  'a1001955': 1,
#  'a1003094': 1,
#  'a1003095': 1,
#  'a1003096': 1,
#  'a1003097': 1,
#  'a1003090': 1,
#  'a1001628': 1,
#  'a1003092': 2,
#  'a1003093': 7,
#  'a1003098': 6,
#  'a1003099': 5,
#  'a1001060': 6,
#  'a1003218': 1,
#  'a1001968': 1,
#  'a1003142': 1,
#  'a1003143': 2,
#  'a1003140': 3,
#  'a1003141': 2,
#  'a1003146': 2,
#  'a1003147': 1,
#  'a1003144': 2,
#  'a1003145': 2,
#  'a1003148': 4,
#  'a1003149': 2,
#  'a1001969': 2,
#  'a1002309': 2,
#  'a1002308': 1,
#  'a1002307': 1,
#  'a1002306': 1,
#  'a1002305': 4,
#  'a1002304': 7,
#  'a1002303': 4,
#  'a1002302': 5,
#  'a1002301': 5,
#  'a1002300': 4,
#  'a1001710': 7,
#  'a1002127': 2,
#  'a1002126': 2,
#  'a1002125': 1,
#  'a1002124': 3,
#  'a1002123': 3,
#  'a1002122': 5,
#  'a1002121': 2,
#  'a1002120': 4,
#  'a1002941': 2,
#  'a1002940': 1,
#  'a1002943': 6,
#  'a1002942': 3,
#  'a1002945': 1,
#  'a1002944': 1,
#  'a1002129': 1,
#  'a1002128': 6,
#  'a1001964': 1,
#  'a1002415': 3,
#  'a1001994': 3,
#  'a1002084': 1,
#  'a1003196': 1,
#  'a1002233': 5,
#  'a1001965': 4,
#  'a1002231': 1,
#  'a1000096': 7,
#  'a1002237': 3,
#  'a1002236': 2,
#  'a1002235': 2,
#  'a1002234': 8,
#  'a1003322': 3,
#  'a1003323': 1,
#  'a1002239': 3,
#  'a1002238': 1,
#  'a1002549': 2,
#  'a1002548': 3,
#  'a1003324': 3,
#  'a1003325': 4,
#  'a1002059': 9,
#  'a1002058': 2,
#  'a1002896': 4,
#  'a1002053': 2,
#  'a1002052': 1,
#  'a1002051': 4,
#  'a1002050': 5,
#  'a1002057': 1,
#  'a1002056': 1,
#  'a1002055': 1,
#  'a1002054': 2,
#  'a1002856': 3,
#  'a1003190': 2,
#  'a1002890': 4,
#  'a1002439': 7,
#  'a1002438': 1,
#  'a1002431': 1,
#  'a1002430': 2,
#  'a1002433': 2,
#  'a1002432': 3,
#  'a1002435': 1,
#  'a1002434': 1,
#  'a1002437': 3,
#  'a1002436': 2,
#  'a1000802': 3,
#  'a1000803': 2,
#  'a1000800': 1,
#  'a1000801': 4,
#  'a1000806': 1,
#  'a1000807': 3,
#  'a1000804': 3,
#  'a1000805': 8,
#  'a1000808': 2,
#  'a1000809': 3,
#  'a1001049': 2,
#  'a1001048': 9,
#  'a1001825': 1,
#  'a1001824': 2,
#  'a1001823': 2,
#  'a1001822': 1,
#  'a1001821': 1,
#  'a1001820': 6,
#  'a1001041': 3,
#  'a1001040': 3,
#  'a1001043': 4,
#  'a1001042': 1,
#  'a1001045': 1,
#  'a1001044': 2,
#  'a1001047': 4,
#  'a1001046': 2,
#  'a1001311': 7,
#  'a1001310': 2,
#  'a1000798': 1,
#  'a1000799': 3,
#  'a1001315': 1,
#  'a1001314': 5,
#  'a1001317': 3,
#  'a1001316': 3,
#  'a1000792': 1,
#  'a1000793': 3,
#  'a1000790': 1,
#  'a1000791': 1,
#  'a1000796': 1,
#  'a1000797': 1,
#  'a1000794': 3,
#  'a1000795': 3,
#  'a1002788': 2,
#  'a1001959': 2,
#  'a1001958': 1,
#  'a1001229': 2,
#  'a1001228': 1,
#  'a1001225': 4,
#  'a1001224': 2,
#  'a1001227': 1,
#  'a1001226': 3,
#  'a1001221': 3,
#  'a1001220': 3,
#  'a1001223': 5,
#  'a1001222': 2,
#  'a1000578': 4,
#  'a1000579': 1,
#  'a1000576': 1,
#  'a1000577': 3,
#  'a1000574': 1,
#  'a1000575': 2,
#  'a1000572': 1,
#  'a1000573': 9,
#  'a1000570': 6,
#  'a1000571': 1,
#  'a1001557': 6,
#  'a1001556': 2,
#  'a1001555': 11,
#  'a1001554': 6,
#  'a1001553': 1,
#  'a1001552': 4,
#  'a1001551': 1,
#  'a1001550': 3,
#  'a1001559': 4,
#  'a1001558': 1,
#  'a1000978': 5,
#  'a1000979': 2,
#  'a1001712': 3,
#  'a1000972': 1,
#  'a1000973': 2,
#  'a1000970': 3,
#  'a1000971': 2,
#  'a1000976': 2,
#  'a1000977': 3,
#  'a1000974': 2,
#  'a1000975': 2,
#  'a1000158': 5,
#  'a1000159': 3,
#  'a1000154': 3,
#  'a1000155': 8,
#  'a1000156': 1,
#  'a1000157': 3,
#  'a1000150': 2,
#  'a1000151': 2,
#  'a1000152': 1,
#  'a1000153': 8,
#  'a1000950': 9,
#  'a1000374': 4,
#  'a1000375': 2,
#  'a1000376': 2,
#  'a1000377': 1,
#  'a1000370': 9,
#  'a1000371': 2,
#  'a1000372': 14,
#  'a1000373': 6,
#  'a1000722': 2,
#  'a1000378': 3,
#  'a1000379': 3,
#  'a1002912': 4,
#  'a1002913': 4,
#  'a1002910': 1,
#  'a1000208': 18,
#  'a1000209': 8,
#  'a1002911': 2,
#  'a1000200': 3,
#  'a1000201': 4,
#  'a1000202': 2,
#  'a1000203': 2,
#  'a1000204': 2,
#  'a1000205': 8,
#  'a1000206': 1,
#  'a1000207': 1,
#  'a1002914': 1,
#  'a1002915': 2,
#  'a1003087': 3,
#  'a1003086': 2,
#  'a1003085': 1,
#  'a1003084': 2,
#  'a1003083': 5,
#  'a1003082': 2,
#  'a1003081': 1,
#  'a1003080': 8,
#  'a1003089': 1,
#  'a1003088': 4,
#  'a1002502': 1,
#  'a1003155': 1,
#  'a1003154': 2,
#  'a1003157': 2,
#  'a1003156': 2,
#  'a1003151': 2,
#  'a1003150': 10,
#  'a1003153': 4,
#  'a1003152': 1,
#  'a1003159': 3,
#  'a1003158': 1,
#  'a1001922': 2,
#  'a1001923': 4,
#  'a1001920': 3,
#  'a1001921': 1,
#  'a1001926': 11,
#  'a1002681': 2,
#  'a1001291': 1,
#  'a1001924': 1,
#  'a1001925': 5,
#  'a1002332': 2,
#  'a1001841': 1,
#  'a1002330': 1,
#  'a1002331': 3,
#  'a1002336': 5,
#  'a1002337': 1,
#  'a1002334': 1,
#  'a1001840': 2,
#  'a1002338': 2,
#  'a1002339': 2,
#  'a1001843': 2,
#  'a1001842': 5,
#  'a1003316': 1,
#  'a1001845': 2,
#  'a1002456': 5,
#  'a1001844': 2,
#  'a1002688': 2,
#  'a1002689': 4,
#  'a1002938': 1,
#  'a1001847': 7,
#  'a1002682': 2,
#  'a1002683': 2,
#  'a1002680': 1,
#  'a1001846': 1,
#  'a1002686': 2,
#  'a1002687': 11,
#  'a1002684': 2,
#  'a1002685': 2,
#  'a1001105': 2,
#  'a1001952': 3,
#  'a1002206': 1,
#  'a1002207': 2,
#  'a1002204': 2,
#  'a1002205': 6,
#  'a1002202': 6,
#  'a1002203': 5,
#  'a1002200': 4,
#  'a1002201': 5,
#  'a1003335': 1,
#  'a1003334': 4,
#  'a1003337': 3,
#  'a1001103': 3,
#  'a1003331': 2,
#  'a1003330': 5,
#  'a1002208': 4,
#  'a1002209': 2,
#  'a1001951': 2,
#  'a1003020': 2,
#  'a1002068': 5,
#  'a1002069': 1,
#  'a1002066': 8,
#  'a1002067': 3,
#  'a1002064': 2,
#  'a1002065': 2,
#  'a1002062': 5,
#  'a1001339': 3,
#  'a1002060': 4,
#  'a1002061': 3,
#  'a1002840': 2,
#  'a1002841': 1,
#  'a1002842': 7,
#  'a1001338': 1,
#  'a1002844': 2,
#  'a1002845': 1,
#  'a1002598': 4,
#  'a1002599': 4,
#  'a1002596': 2,
#  'a1001449': 1,
#  'a1002594': 4,
#  'a1002595': 1,
#  'a1002592': 4,
#  'a1002593': 1,
#  'a1002590': 2,
#  'a1001448': 1,
#  'a1002615': 3,
#  'a1002614': 1,
#  'a1002830': 6,
#  'a1002617': 1,
#  'a1001445': 8,
#  'a1002118': 2,
#  'a1002119': 1,
#  'a1002448': 2,
#  'a1002449': 5,
#  'a1001332': 4,
#  'a1002112': 4,
#  'a1002113': 2,
#  'a1002110': 3,
#  'a1002111': 5,
#  'a1002116': 3,
#  'a1001447': 5,
#  'a1002114': 2,
#  'a1002115': 2,
#  'a1001140': 1,
#  'a1001141': 1,
#  'a1001142': 2,
#  'a1001143': 3,
#  'a1001144': 1,
#  'a1001145': 1,
#  'a1001146': 1,
#  'a1001147': 3,
#  'a1001148': 2,
#  'a1001149': 1,
#  'a1002612': 4,
#  'a1001440': 3,
#  'a1001335': 1,
#  'a1003117': 3,
#  'a1001334': 3,
#  'a1003210': 3,
#  'a1001444': 1,
#  'a1000815': 2,
#  'a1000814': 1,
#  'a1000817': 1,
#  'a1000816': 1,
#  'a1000811': 2,
#  'a1000810': 2,
#  'a1000813': 1,
#  'a1000812': 10,
#  'a1001812': 1,
#  'a1001813': 1,
#  'a1001810': 19,
#  'a1001811': 3,
#  'a1000819': 5,
#  'a1000818': 3,
#  'a1001814': 2,
#  'a1001815': 3,
#  'a1001038': 1,
#  'a1001039': 1,
#  'a1001034': 1,
#  'a1001035': 2,
#  'a1001036': 1,
#  'a1001037': 2,
#  'a1001030': 5,
#  'a1001031': 5,
#  'a1001032': 3,
#  'a1001033': 1,
#  'a1001364': 3,
#  'a1001365': 3,
#  'a1001366': 1,
#  'a1001367': 1,
#  'a1000789': 3,
#  'a1000788': 4,
#  'a1001362': 2,
#  'a1001363': 2,
#  'a1000785': 1,
#  'a1000784': 3,
#  'a1000787': 2,
#  'a1000786': 3,
#  'a1001368': 3,
#  'a1000780': 2,
#  'a1000783': 2,
#  'a1000782': 4,
#  'a1001954': 1,
#  'a1001729': 4,
#  'a1001782': 4,
#  'a1001783': 1,
#  'a1001780': 1,
#  'a1001781': 3,
#  'a1001786': 2,
#  'a1001787': 2,
#  'a1001784': 1,
#  'a1001785': 2,
#  'a1001966': 4,
#  'a1001967': 1,
#  'a1001788': 2,
#  'a1001789': 2,
#  'a1001962': 2,
#  'a1001963': 1,
#  'a1001960': 4,
#  'a1001961': 6,
#  'a1000561': 2,
#  'a1000560': 4,
#  'a1000563': 2,
#  'a1000562': 2,
#  'a1000565': 4,
#  'a1000564': 2,
#  'a1000567': 3,
#  'a1000566': 4,
#  'a1000569': 2,
#  'a1000568': 2,
#  'a1001560': 1,
#  'a1001561': 1,
#  'a1001566': 2,
#  'a1001567': 6,
#  'a1001564': 4,
#  'a1001565': 5,
#  'a1001768': 1,
#  'a1001769': 2,
#  'a1001760': 2,
#  'a1001761': 2,
#  'a1001762': 1,
#  'a1001763': 7,
#  'a1001764': 2,
#  'a1001765': 1,
#  'a1001766': 1,
#  'a1001767': 3,
#  'a1000969': 2,
#  'a1000968': 1,
#  'a1000965': 2,
#  'a1000964': 1,
#  'a1000967': 2,
#  'a1000966': 1,
#  'a1000961': 1,
#  'a1000960': 2,
#  'a1000962': 3,
#  'a1000149': 4,
#  'a1000148': 4,
#  'a1000147': 3,
#  'a1000146': 5,
#  'a1000145': 2,
#  'a1000144': 6,
#  'a1000143': 8,
#  'a1000142': 1,
#  'a1000141': 1,
#  'a1000140': 1,
#  'a1000367': 2,
#  'a1000365': 3,
#  'a1000364': 9,
#  'a1000363': 4,
#  'a1000362': 3,
#  'a1000361': 4,
#  'a1000360': 6,
#  'a1000369': 1,
#  'a1000368': 5,
#  'a1002981': 1,
#  'a1002980': 2,
#  'a1003319': 4,
#  'a1000731': 3,
#  'a1000219': 5,
#  'a1000218': 1,
#  'a1000213': 2,
#  'a1000212': 1,
#  'a1000211': 5,
#  'a1000210': 2,
#  'a1000217': 1,
#  'a1000216': 1,
#  'a1000215': 1,
#  'a1000214': 2,
#  'a1003064': 5,
#  'a1002745': 1,
#  'a1001725': 3,
#  'a1000901': 2,
#  'a1001865': 5,
#  'a1000550': 2,
#  'a1002461': 2,
#  'a1000551': 5,
#  'a1002835': 3,
#  'a1002889': 4,
#  'a1000553': 7,
#  'a1002464': 5,
#  'a1003188': 3,
#  'a1003189': 4,
#  'a1003186': 10,
#  'a1000006': 1,
#  'a1003184': 4,
#  ...}

# %%
data['basketSize'] = data['orderID'].apply(lambda id: dict_basket_size[id])

# %%
data['basketQuantity'] = data['orderID'].apply(lambda id: dict_basket_total_quantity[id])

# %%
data
# Out:
#        orderID   orderDate articleID  colorCode sizeCode  productGroup  \
# 0     a1000001  2014-01-01  i1000382       1972       44           3.0
# 1     a1000001  2014-01-01  i1000550       3854       44           3.0
# 2     a1000002  2014-01-01  i1001991       2974       38           8.0
# 3     a1000002  2014-01-01  i1001999       1992       38           8.0
# 4     a1000003  2014-01-01  i1001942       1968       42           8.0
# 5     a1000003  2014-01-01  i1001942       1972       42           8.0
# 6     a1000003  2014-01-01  i1001974       1001       42           8.0
# 7     a1000003  2014-01-01  i1001976       3976       44           8.0
# 8     a1000003  2014-01-01  i1002392       2493       42          13.0
# 9     a1000004  2014-01-01  i1002457       1001       42          14.0
# 10    a1000005  2014-01-01  i1000366       1968       42           3.0
# 11    a1000005  2014-01-01  i1000406       3972       40           3.0
# 12    a1000005  2014-01-01  i1000406       3972       42           3.0
# 13    a1000006  2014-01-01  i1001957       3001       38           8.0
# 14    a1000006  2014-01-01  i1001993       3974       38           8.0
# 15    a1000007  2014-01-01  i1000012       1974       34           1.0
# 16    a1000007  2014-01-01  i1000024       2974       36           1.0
# 17    a1000007  2014-01-01  i1000235       1974       27           2.0
# 18    a1000008  2014-01-01  i1001642       1001       44           7.0
# 19    a1000009  2014-01-01  i1001767       1999       44           8.0
# 20    a1000009  2014-01-01  i1001768       1995       44           8.0
# 21    a1000009  2014-01-01  i1002263       1001       44          13.0
# 22    a1000009  2014-01-01  i1002266       1001       44          13.0
# 23    a1000009  2014-01-01  i1002268       1001       44          13.0
# 24    a1000009  2014-01-01  i1002269       3001       44          13.0
# 25    a1000010  2014-01-01  i1001485       1978       34           6.0
# 26    a1000010  2014-01-01  i1001486       1953       36           6.0
# 27    a1000010  2014-01-01  i1001486       1978       36           6.0
# 28    a1000010  2014-01-01  i1002067       1970       32           9.0
# 29    a1000010  2014-01-01  i1002243       3978       34          13.0
# ...        ...         ...       ...        ...      ...           ...
# 9970  a1003367  2014-01-05  i1000422       1972       38           3.0
# 9971  a1003367  2014-01-05  i1000544       1927       38           3.0
# 9972  a1003367  2014-01-05  i1000567       1953       40           3.0
# 9973  a1003367  2014-01-05  i1000571       2493       40           3.0
# 9974  a1003367  2014-01-05  i1000580       2493       40           3.0
# 9975  a1003367  2014-01-05  i1000580       2934       40           3.0
# 9976  a1003368  2014-01-05  i1000608       1996       42           3.0
# 9977  a1003369  2014-01-05  i1003000       3975        I          17.0
# 9978  a1003369  2014-01-05  i1003000       3978        I          17.0
# 9979  a1003370  2014-01-05  i1000548       3953       36           3.0
# 9980  a1003370  2014-01-05  i1000548       3976       36           3.0
# 9981  a1003370  2014-01-05  i1001344       1854       38           5.0
# 9982  a1003370  2014-01-05  i1001345       1981       38           5.0
# 9983  a1003370  2014-01-05  i1001346       1976       40           5.0
# 9984  a1003370  2014-01-05  i1001977       3976       36           8.0
# 9985  a1003370  2014-01-05  i1002984       3974        I          17.0
# 9986  a1003370  2014-01-05  i1002984       3976        I          17.0
# 9987  a1003371  2014-01-05  i1000339       1950       38           3.0
# 9988  a1003371  2014-01-05  i1000395       2972       36           3.0
# 9989  a1003371  2014-01-05  i1001929       1950       36           8.0
# 9990  a1003371  2014-01-05  i1001929       1956       36           8.0
# 9991  a1003371  2014-01-05  i1002984       3974        I          17.0
# 9992  a1003371  2014-01-05  i1002989       3974        I          17.0
# 9993  a1003372  2014-01-05  i1001317       1999       42           5.0
# 9994  a1003372  2014-01-05  i1001373       1999       42           5.0
# 9995  a1003373  2014-01-05  i1000185       6698       27           2.0
# 9996  a1003373  2014-01-05  i1000185       6698       28           2.0
# 9997  a1003374  2014-01-05  i1000321       1493       40           3.0
# 9998  a1003375  2014-01-05  i1000013       1966       38           1.0
# 9999  a1003375  2014-01-05  i1001514       1995       38           6.0
#
#       quantity   price     rrp voucherID  voucherAmount customerID  deviceID  \
# 0            1   10.00   29.99         0            0.0   c1010575         2
# 1            1   20.00   39.99         0            0.0   c1010575         2
# 2            1   35.00   49.99         0            0.0   c1045905         4
# 3            1   49.99   49.99         0            0.0   c1045905         4
# 4            1   10.00   35.99         0            0.0   c1089295         2
# 5            1   10.00   35.99         0            0.0   c1089295         2
# 6            1   25.00   39.99         0            0.0   c1089295         2
# 7            1   15.00   39.99         0            0.0   c1089295         2
# 8            0    0.00   59.99         0            0.0   c1089295         2
# 9            1   89.99   89.99         0            0.0   c1050116         3
# 10           1   15.00   39.99         0            0.0   c1089296         2
# 11           1   10.00   29.99         0            0.0   c1089296         2
# 12           1   10.00   29.99         0            0.0   c1089296         2
# 13           0    0.00   39.99         0            0.0   c1089297         2
# 14           1   25.00   39.99         0            0.0   c1089297         2
# 15           1   15.00   49.99         0            0.0   c1084986         2
# 16           1   20.00   69.99         0            0.0   c1084986         2
# 17           1   15.00   59.99         0            0.0   c1084986         2
# 18           1  110.00  149.99         0            0.0   c1089298         2
# 19           1   39.99   39.99         0            0.0   c1054307         2
# 20           1   39.99   39.99         0            0.0   c1054307         2
# 21           1   69.99   69.99         0            0.0   c1054307         2
# 22           1   59.99   59.99         0            0.0   c1054307         2
# 23           1   69.99   69.99         0            0.0   c1054307         2
# 24           1   69.99   69.99         0            0.0   c1054307         2
# 25           1   50.00   69.99         0            0.0   c1089299         2
# 26           1   55.00   79.99         0            0.0   c1089299         2
# 27           1   55.00   79.99         0            0.0   c1089299         2
# 28           1   10.00   49.99         0            0.0   c1089299         2
# 29           1   20.00   49.99         0            0.0   c1089299         2
# ...        ...     ...     ...       ...            ...        ...       ...
# 9970         1   15.00   39.99  v1000078           10.0   c1067820         2
# 9971         1   20.00   39.99  v1000078           10.0   c1067820         2
# 9972         1   15.00   19.99  v1000078           10.0   c1067820         2
# 9973         1   12.00   17.99  v1000078           10.0   c1067820         2
# 9974         1   15.00   19.99  v1000078           10.0   c1067820         2
# 9975         1   15.00   19.99  v1000078           10.0   c1067820         2
# 9976         1   49.99   49.99  v1000078           10.0   c1073743         2
# 9977         1   15.00   25.99         0            0.0   c1090631         2
# 9978         1   15.00   25.99         0            0.0   c1090631         2
# 9979         1   20.00   27.99  v1000078           10.0   c1068442         2
# 9980         1   20.00   27.99  v1000078           10.0   c1068442         2
# 9981         1   39.99   39.99  v1000078           10.0   c1068442         2
# 9982         1   39.99   39.99  v1000078           10.0   c1068442         2
# 9983         1   35.00   69.99  v1000078           10.0   c1068442         2
# 9984         1   15.00   39.99  v1000078           10.0   c1068442         2
# 9985         1   10.00   27.99  v1000078           10.0   c1068442         2
# 9986         1   10.00   27.99  v1000078           10.0   c1068442         2
# 9987         1    5.00   19.99  v1000078           10.0   c1003172         2
# 9988         1    5.00   22.99  v1000078           10.0   c1003172         2
# 9989         1   10.00   29.95  v1000078           10.0   c1003172         2
# 9990         1   10.00   29.95  v1000078           10.0   c1003172         2
# 9991         1   10.00   27.99  v1000078           10.0   c1003172         2
# 9992         1   10.00   29.99  v1000078           10.0   c1003172         2
# 9993         1   49.99   49.99  v1000078           10.0   c1001599         2
# 9994         1   59.99   59.99  v1000078           10.0   c1001599         2
# 9995         1   50.00   69.99  v1000078           10.0   c1056344         2
# 9996         1   50.00   69.99  v1000078           10.0   c1056344         2
# 9997         1   25.99   25.99         0            0.0   c1090629         4
# 9998         1   15.00   49.99         0            0.0   c1008985         2
# 9999         1   49.99   49.99         0            0.0   c1008985         2
#
#      paymentMethod  returnQuantity  basketSize  basketQuantity
# 0             BPRG               0           2               2
# 1             BPRG               0           2               2
# 2             BPRG               0           2               2
# 3             BPRG               1           2               2
# 4         PAYPALVC               0           5               4
# 5         PAYPALVC               0           5               4
# 6         PAYPALVC               0           5               4
# 7         PAYPALVC               0           5               4
# 8         PAYPALVC               0           5               4
# 9             BPRG               1           1               1
# 10            BPRG               1           3               3
# 11            BPRG               1           3               3
# 12            BPRG               1           3               3
# 13            BPRG               0           2               1
# 14            BPRG               0           2               1
# 15            BPRG               0           3               3
# 16            BPRG               1           3               3
# 17            BPRG               1           3               3
# 18            BPRG               1           1               1
# 19            BPRG               0           6               6
# 20            BPRG               0           6               6
# 21            BPRG               0           6               6
# 22            BPRG               0           6               6
# 23            BPRG               1           6               6
# 24            BPRG               0           6               6
# 25            BPRG               1           6               6
# 26            BPRG               1           6               6
# 27            BPRG               1           6               6
# 28            BPRG               1           6               6
# 29            BPRG               1           6               6
# ...            ...             ...         ...             ...
# 9970      PAYPALVC               1           7               7
# 9971      PAYPALVC               0           7               7
# 9972      PAYPALVC               1           7               7
# 9973      PAYPALVC               0           7               7
# 9974      PAYPALVC               0           7               7
# 9975      PAYPALVC               0           7               7
# 9976          BPRG               1           1               1
# 9977          BPRG               0           2               2
# 9978          BPRG               0           2               2
# 9979          BPRG               1           8               8
# 9980          BPRG               1           8               8
# 9981          BPRG               1           8               8
# 9982          BPRG               1           8               8
# 9983          BPRG               1           8               8
# 9984          BPRG               1           8               8
# 9985          BPRG               1           8               8
# 9986          BPRG               1           8               8
# 9987          BPRG               1           6               6
# 9988          BPRG               0           6               6
# 9989          BPRG               1           6               6
# 9990          BPRG               1           6               6
# 9991          BPRG               0           6               6
# 9992          BPRG               1           6               6
# 9993          BPRG               0           2               2
# 9994          BPRG               1           2               2
# 9995          BPRG               0           2               2
# 9996          BPRG               1           2               2
# 9997          BPRG               1           1               1
# 9998          BPRG               1           2               2
# 9999          BPRG               0           2               2
#
# [10000 rows x 17 columns]
